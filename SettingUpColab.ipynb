# %% [markdown]
# This cell is used to mount the google drive(mounting google drive means to give access of our google drive data to the google colab virtual machine), so that we can use the uploaded datasets for our training.

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# gpg: keybox '/tmp/tmpzosw2pv1/pubring.gpg' created
# gpg: /tmp/tmpzosw2pv1/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...
# ··········

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %%
# !ls drive
# Out:
# A low cost vision based localization system.html.odt
# Application Form 2018.odt
# Applications of Hydrophobic materials.pdf
# BE Projects.odt
# Blue Whale.docx
# Blue Whale.docx.odt
# CDS_2015-2016.xlsx
# Chemistry lor.odt
# Chemistry lor.odt (e7f64653)
# Citi Credit card statement.htm.odt
# Citi Credit card statement.htm.odt (973c6a60)
# Colab_Notebooks
# College Essay.odt
# Colleges login.ods
# Common app essay.odt
# Common app final.odt
# Copy of Exchange rate determaination.pdf
# Counselors recommendation.docx
# Counselors recommendation.odt
# Dadji Photos.pdf
# Document (5).docx
# Document (5).docx.odt
# drugs.pdf
# Emailing New Doc 2.pdf
# || Engineering Hallticket ||
# Essays
# Extracurricular final.odt
# Extracurricular final purdue.odt
# Extracurricular.odt
# final draft.odt
# Gap reason final.docx
# gear manufracturing presentation.pdf
# Georgia 1.docx
# Georgia 1.odt
# Georgia 2.odt
# Georgia Tech passport
# Google Keep Document.odt
# Hydrophobics Materials.pdf
# ...

# %%
# !ls
#ls will not give you proper information, instead of using shell commands it would be better to use
# os commands for managing directories

#wacth this for easier understanding: https://youtu.be/1PrnA4pVm5o, watch from around 6min

#must run this only once
#os.chdir('drive/Colab_Notebooks/Semantic_Segmentation')

import os
cwd = os.getcwd()
print(cwd)

import helper
from PIL import Image

Image.open('data/data_road/testing/image_2/uu_000099.png')

import project_tests as test
print("Successful")
# Out:
# data	   main2.ipynb	       main.py		 __pycache__
# helper.py  main_jupyter.ipynb  project_tests.py  SemanticSegmentation.ipynb
# /content/drive/Colab_Notebooks/Semantic_Segmentation
# Successful
